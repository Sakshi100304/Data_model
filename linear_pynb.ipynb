# %% [markdown]
# <a href="https://colab.research.google.com/github/Sakshi100304/Data_model/blob/main/linear_pynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
df = pd.read_csv("https://raw.githubusercontent.com/ybifoundation/Dataset/main/Salary%20Data.csv")
df.head()
df.isnull().sum()
df.duplicated().sum()
df.describe()
x = df[["Experience Years"]]
y = df["Salary"]
plt.scatter(x, y)
plt.show()
df.shape
x_train,x_test,y_train,y_test = train_test_split(x,y,train_size=0.7,random_state=2529)

# %%
x_train.shape,x_test.shape,y_train.shape,y_test.shape
lr = LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lr.score(x_test,y_test)*100
# Out:
# 96.0233432146844

# %%
Year = int(input("Enter you Experienced in year :"))
salary = lr.predict([[Year]])
print(salary)
# Out:
# Enter you Experienced in year :7
# [92436.27773742]
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
x = df[["Experience Years"]]
y = df["Salary"]
plt.figure(figsize=(10,3))
plt.scatter(x, y)
plt.plot(x, lr.predict(x),color="green")
plt.xlabel("Experience Years")
plt.ylabel("Salary")
plt.show()
